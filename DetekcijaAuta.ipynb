# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="f6rDbLQ5dGQFZrbgrMDr")
project = rf.workspace("ki-ss24").project("car-brands-ygzoj")
version = project.version(7)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ---------------------------------------------------------------------------
# RoboflowError                             Traceback (most recent call last)
# <ipython-input-1-59727fe9c17e> in <cell line: 0>()
#       3 from roboflow import Roboflow
#       4 rf = Roboflow(api_key="f6rDbLQ5dGQFZrbgrMDr")
# ----> 5 project = rf.workspace("ki-ss24").project("car-brands-ygzoj")
#       6 version = project.version(7)
#       7 dataset = version.download("yolov11")
#
# /usr/local/lib/python3.11/dist-packages/roboflow/core/workspace.py in project(self, project_id)
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 910.1/910.1 kB 22.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLO11n model
model = YOLO("yolo11l.pt")

# Train the mdel on the COCO8 example dataset for 20 epochs
results = model.train(data="/content/Car-Brands-7/data.yaml", epochs=30,imgsz=640)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 49.0M/49.0M [00:00<00:00, 135MB/s]
# Ultralytics 8.3.62 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from PIL import Image
from ultralytics import YOLO
# Ucitavamo nase najbolje tezine....odnosno nas model....moze i ovako...ili onaj sacuvani
model = YOLO('/content/runs/detect/train2/weights/best.pt')
# Detekcija na slici proba.jpg
results = model('/content/golf 4.jpg')
# Prikaz rezultata
for r in results:
    im_array = r.plot()  # plotuje se isto U BGR
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL slika
    im.show()  # prikaz slike
    im.save('results4.jpg')  # cuvaj se
# Out:
# image 1/1 /content/golf 4.jpg: 416x640 2 vws, 55.6ms
# Speed: 2.8ms preprocess, 55.6ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
